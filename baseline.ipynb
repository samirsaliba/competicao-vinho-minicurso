# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv', index_col=0)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 150             7.3             0.330         0.47             2.1      0.077
# 1164            9.0             0.785         0.24             1.7      0.078
# 285             9.9             0.590         0.07             3.4      0.102
# 1456            6.0             0.540         0.06             1.8      0.050
# 1389            6.7             0.480         0.02             2.2      0.080
# ...             ...               ...          ...             ...        ...
# 174             7.3             0.380         0.21             2.0      0.080
# 915             8.6             0.315         0.40             2.2      0.079
# 640             9.9             0.540         0.45             2.3      0.071
# 661             7.5             0.420         0.31             1.6      0.080
# 1185            7.0             0.430         0.30             2.0      0.085
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 150                   5.0                  11.0  0.99580  3.33       0.53
# 1164                 10.0                  21.0  0.99692  3.29       0.67
# 285                  32.0                  71.0  1.00015  3.31       0.71
# 1456                 38.0                  89.0  0.99236  3.30       0.50
# 1389                 36.0                 111.0  0.99524  3.10       0.53
# ...                   ...                   ...      ...   ...        ...
# 174                   7.0                  35.0  0.99610  3.33       0.47
# 915                   3.0                   6.0  0.99512  3.27       0.67
# 640                  16.0                  40.0  0.99910  3.39       0.62
# 661                  15.0                  42.0  0.99780  3.31       0.64
# 1185                  6.0                  39.0  0.99346  3.33       0.46
#
#       alcohol  quality
# 150     10.30        0
# 1164    10.00        0
# 285      9.80        0
# 1456    10.55        0
# 1389     9.70        0
# ...       ...      ...
# 174      9.50        0
# 915     11.90        0
# 640      9.40        0
# 661      9.00        0
# 1185    11.90        0
#
# [1359 rows x 12 columns]

# %%
counts = df.quality.value_counts(normalize=True)
counts
# Out:
# 0    0.864606
# 1    0.135394
# Name: quality, dtype: float64

# %%
X = df.drop(columns='quality')
y = df.loc[:, 'quality'].to_numpy()

X.shape, y.shape
# Out:
# ((1359, 11), (1359,))

# %%
X.head(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 150             7.3             0.330         0.47             2.1      0.077
# 1164            9.0             0.785         0.24             1.7      0.078
# 285             9.9             0.590         0.07             3.4      0.102
# 1456            6.0             0.540         0.06             1.8      0.050
# 1389            6.7             0.480         0.02             2.2      0.080
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 150                   5.0                  11.0  0.99580  3.33       0.53
# 1164                 10.0                  21.0  0.99692  3.29       0.67
# 285                  32.0                  71.0  1.00015  3.31       0.71
# 1456                 38.0                  89.0  0.99236  3.30       0.50
# 1389                 36.0                 111.0  0.99524  3.10       0.53
#
#       alcohol
# 150     10.30
# 1164    10.00
# 285      9.80
# 1456    10.55
# 1389     9.70

# %% [markdown]
# ## Normalização

# %%
from sklearn.preprocessing import StandardScaler

colunas = X.columns
scaler = StandardScaler()
X = scaler.fit_transform(X)

X = pd.DataFrame(X, columns = colunas)
X.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.596546         -1.092653     1.015845       -0.301099  -0.230762
# 1       0.380624          1.410538    -0.163572       -0.587273  -0.209644
# 2       0.897949          0.337742    -1.035315        0.628967   0.297194
# 3      -1.343793          0.062666    -1.086594       -0.515729  -0.800955
# 4      -0.941429         -0.267425    -1.291710       -0.229555  -0.167407
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -1.049570             -1.065063 -0.491006  0.137108  -0.755970
# 1            -0.564081             -0.763149  0.105867 -0.123038   0.070454
# 2             1.572068              0.746421  1.827207  0.007035   0.306575
# 3             2.154655              1.289866 -2.324260 -0.058002  -0.933061
# 4             1.960459              1.954077 -0.789443 -1.358733  -0.755970
#
#     alcohol
# 0 -0.127628
# 1 -0.407881
# 2 -0.594717
# 3  0.105917
# 4 -0.688135

# %% [markdown]
# ## Separando entre conjuntos de Treino, Teste

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=5, test_size=0.20, random_state=0)
sss.get_n_splits(X, y)
# Out:
# 5

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score
)

def eval_metrics(actual, predicted):
     return {
         'accuracy': accuracy_score(actual, predicted),
         'precision': precision_score(actual, predicted),
         'recall': recall_score(actual, predicted),
         'f1':f1_score(actual, predicted, average='micro')
     }

# %%
X.shape, y.shape
# Out:
# ((1359, 11), (1359,))

# %%
from sklearn.linear_model import Perceptron
from tqdm import tqdm

perceptron_scores = []
perceptron_metrics = []

iteracao = 0
for train_index, test_index in tqdm(sss.split(X, y)):
    X_train, X_test = X.loc[train_index, :], X.loc[test_index, :]
    y_train, y_test = y[train_index], y[test_index]
    
    model = Perceptron(tol=1e-3, random_state=0)
    model.fit(X_train, y_train)
    
    score = model.score(X_test, y_test)
    display(score)
    perceptron_scores.append(score)
    
    # Para mais metricas:
    y_pred = model.predict(X_test)
    metrics = eval_metrics(y_test, y_pred)
    perceptron_metrics.append({
        iteracao: metrics
    })
    
    iteracao+=1
# Out:
# 0it [00:00, ?it/s]
# 0.7867647058823529
# 0.8639705882352942
# 0.8529411764705882
# 0.8382352941176471
# 0.8602941176470589
# 5it [00:00, 119.05it/s]

# %%
perceptron_metrics
# Out:
# [{0: {'accuracy': 0.7867647058823529,
#    'precision': 0.36,
#    'recall': 0.7297297297297297,
#    'f1': 0.7867647058823529}},
#  {1: {'accuracy': 0.8639705882352942,
#    'precision': 0.5,
#    'recall': 0.10810810810810811,
#    'f1': 0.8639705882352942}},
#  {2: {'accuracy': 0.8529411764705882,
#    'precision': 0.44,
#    'recall': 0.2972972972972973,
#    'f1': 0.8529411764705882}},
#  {3: {'accuracy': 0.8382352941176471,
#    'precision': 0.18181818181818182,
#    'recall': 0.05405405405405406,
#    'f1': 0.8382352941176471}},
#  {4: {'accuracy': 0.8602941176470589,
#    'precision': 0.47368421052631576,
#    'recall': 0.24324324324324326,
#    'f1': 0.8602941176470589}}]

# %% [markdown]
# ## Preparando o arquivo de submissão

# %%
df_test = pd.read_csv('x_test.csv', index_col=0)

df_test.head(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 177             7.5              0.52         0.42             2.3      0.087
# 384             7.7              0.51         0.28             2.1      0.087
# 1324            6.7              0.46         0.24             1.7      0.077
# 1076            9.9              0.32         0.56             2.0      0.073
# 927             8.4              0.67         0.19             2.2      0.093
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 177                   8.0                  38.0  0.99720  3.58       0.61
# 384                  23.0                  54.0  0.99800  3.42       0.74
# 1324                 18.0                  34.0  0.99480  3.39       0.60
# 1076                  3.0                   8.0  0.99534  3.15       0.73
# 927                  11.0                  75.0  0.99736  3.20       0.59
#
#       alcohol
# 177      10.5
# 384       9.2
# 1324     10.6
# 1076     11.4
# 927       9.2

# %%
colunas = df_test.columns
indices = df_test.index

X = scaler.fit_transform(df_test)
X = pd.DataFrame(X, columns = colunas)
X.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.411479         -0.020655     0.798754       -0.231567   0.047366
# 1      -0.296647         -0.082233     0.073791       -0.367616   0.047366
# 2      -0.870803         -0.390127    -0.133341       -0.639713  -0.173799
# 3       0.966496         -1.252228     1.523716       -0.435640  -0.262265
# 4       0.105262          0.903026    -0.392257       -0.299591   0.180066
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.729542             -0.303226  0.159911  1.633530  -0.286479
# 1             0.597569              0.204908  0.572751  0.614398   0.479429
# 2             0.155198             -0.430260 -1.078610  0.423311  -0.345395
# 3            -1.171913             -1.255977 -0.799943 -1.105386   0.420513
# 4            -0.464120              0.871833  0.242479 -0.786908  -0.404311
#
#     alcohol
# 0  0.149389
# 1 -1.109755
# 2  0.246246
# 3  1.021104
# 4 -1.109755

# %%
y = model.predict(X)

# %%
solucao = {
    'Id':indices,
    'Predicted': y
}

df_solution = pd.DataFrame(solucao)
df_solution.head(5)
# Out:
#      Id  Predicted
# 0   177          0
# 1   384          0
# 2  1324          0
# 3  1076          0
# 4   927          0

# %%
df_solution.to_csv('submission.csv', index=False)
